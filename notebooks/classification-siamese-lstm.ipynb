# %% [markdown]
# ## Installing Packages and Dependencies

# %%
# !pip install --quiet gensim nltk

# %%
from os.path import join

import numpy as np
import pandas as pd

import re
import string

import transformers
from transformers import AutoTokenizer
import gensim
import gensim.downloader
from gensim.models import Word2Vec

import nltk
from nltk.tokenize import word_tokenize

import torch
import torch.nn as nn
import torch.nn.functional as F

from sklearn.model_selection import train_test_split

from torch.utils.data import DataLoader, Dataset

from tqdm.notebook import tqdm

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import accuracy_score, roc_curve, auc, classification_report

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print(device)
# Out:
# cuda

# %% [markdown]
# ## Importing Dataset

# %%
DATA_DIR = join('/content', 'drive', 'MyDrive', 'ay2324 sem1', 'cs3244', 'project', 'data', 'glue')

# %%
train_full_df = pd.read_csv(join(DATA_DIR, 'train.tsv'), sep='\t')
train_full_df.head()
# Out:
#        id    qid1    qid2                                          question1  \
# 0  133273  213221  213222  How is the life of a math student? Could you d...
# 1  402555  536040  536041                How do I control my horny emotions?
# 2  360472  364011  490273       What causes stool color to change to yellow?
# 3  150662  155721    7256                        What can one do after MBBS?
# 4  183004  279958  279959  Where can I find a power outlet for my laptop ...
#
#                                            question2  is_duplicate
# 0  Which level of prepration is enough for the ex...             0
# 1                 How do you control your horniness?             1
# 2  What can cause stool to come out as little balls?             0
# 3                       What do i do after my MBBS ?             1
# 4  Would a second airport in Sydney, Australia be...             0

# %% [markdown]
# ### Null removals

# %%
def remove_nulls(df):
    print(f"Initial dataframe has {len(df)} rows.")
    null_rows = df[df.isnull().values.any(1)]
    print(f"Dataframe has {len(null_rows)} null rows.")
    df = df.dropna(how='any')
    print(f"Dataframe has {len(df)} rows after removing null values.")
    return df

train_full_df = remove_nulls(train_full_df)
# Out:
# Initial dataframe has 363846 rows.
# Dataframe has 0 null rows.
# Dataframe has 363846 rows after removing null values.

# %%
train_full_df.shape
# Out:
# (363846, 6)

# %%
num_samples = len(train_full_df)
num_samples
# Out:
# 363846

# %% [markdown]
# ### Test Dataset

# %%
test_df = pd.read_csv(join(DATA_DIR, 'dev.tsv'), sep='\t')
test_df = remove_nulls(test_df)
test_df.head()
# Out:
# Initial dataframe has 40430 rows.
# Dataframe has 0 null rows.
# Dataframe has 40430 rows after removing null values.
#        id    qid1    qid2                                          question1  \
# 0  201359  303345  303346            Why are African-Americans so beautiful?
# 1  263843   69383  380476  I want to pursue PhD in Computer Science about...
# 2  172974  266948  175089      Is there a reason why we should travel alone?
# 3   15329   29298   29299  Why are people so obsessed with having a girlf...
# 4  209794  314169  314170  What are some good baby girl names starting wi...
#
#                                            question2  is_duplicate
# 0                    Why are hispanics so beautiful?             0
# 1  I handle social media for a non-profit. Should...             0
# 2             What are some reasons to travel alone?             1
# 3                How can a single male have a child?             0
# 4  What are some good baby girl names starting wi...             0

# %%
test_df.shape
# Out:
# (40430, 6)

# %% [markdown]
# ### Train and Dev Dataset

# %%
train_df, dev_df = train_test_split(train_full_df, test_size=0.1, random_state=42)

# %%
len(train_df), len(dev_df)
# Out:
# (327461, 36385)

# %%
train_df.head()
# Out:
#             id    qid1    qid2  \
# 80519    51432   91228   91229
# 349125   52249   92541   92542
# 126605  135176  215925  215926
# 6008    184003  281230  281231
# 292788    5971   11714   11715
#
#                                                 question1  \
# 80519          Which topic is the most followed in Quora?
# 349125  What does it feel like to have sex with a rela...
# 126605                     Can I get back my best friend?
# 6008    Are there solar systems that act like a double...
# 292788                    Why are there only few magnets?
#
#                                                 question2  is_duplicate
# 80519         What topic on Quora has the most followers?             1
# 349125         Is it possible to eat more than you weigh?             0
# 126605   How do I get back to my best friend as my lover?             0
# 6008    As a Navy SEAL do you feel as if people are af...             0
# 292788                     Why is there only few magnets?             1

# %%
dev_df.head()
# Out:
#             id    qid1    qid2  \
# 215130  328831  455423  455424
# 234600   41794   75402   75403
# 118406  184181   56834  281459
# 284746   61939   50127   69389
# 300683  352765  481723   13812
#
#                                                 question1  \
# 215130  Why do some people think that having a baby is...
# 234600  How vulnerable are paratroopers on their desce...
# 118406               Examples of sole proprietorship? The
# 284746  Why don't I get answers for some of my questio...
# 300683               Do Kashmiris wants to join Pakistan?
#
#                                                 question2  is_duplicate
# 215130                   Why is having a baby a blessing?             1
# 234600            Are conventional paratroopers obsolete?             0
# 118406              How are sole proprietorships started?             0
# 284746  Why do some questions get more answers here in...             1
# 300683  Do the people of Kashmir want to join Pakistan...             0

# %% [markdown]
# ### Splitting

# %%
X_train = train_df.iloc[:,:-1]
y_train = train_df.iloc[:, -1]

# %%
X_test = test_df.iloc[:,:-1]
y_test = test_df.iloc[:,-1]

# %%
X_dev = dev_df.iloc[:,:-1]
y_dev = dev_df.iloc[:,-1]

# %% [markdown]
# ## Cleaning

# %%
def clean_text(text):
    text = text.lower() # lower case
    text = re.sub('\s+\n+', ' ', text)
    text = re.sub(f"[{''.join(char for char in string.punctuation if char != '?')}]", ' ', text) # remove punctuation
    text = re.sub(r'[^a-zA-Z0-9\s?]', ' ', text) # remove special chars

    return text

demo_qn = "What's the meaning of life?"
clean_text(demo_qn)
# Out:
# 'what s the meaning of life?'

# %%
X_train['q1_cleaned'] = X_train['question1'].apply(clean_text)
X_train['q2_cleaned'] = X_train['question2'].apply(clean_text)
X_train.head()
# Out:
#             id    qid1    qid2  \
# 80519    51432   91228   91229
# 349125   52249   92541   92542
# 126605  135176  215925  215926
# 6008    184003  281230  281231
# 292788    5971   11714   11715
#
#                                                 question1  \
# 80519          Which topic is the most followed in Quora?
# 349125  What does it feel like to have sex with a rela...
# 126605                     Can I get back my best friend?
# 6008    Are there solar systems that act like a double...
# 292788                    Why are there only few magnets?
#
#                                                 question2  \
# 80519         What topic on Quora has the most followers?
# 349125         Is it possible to eat more than you weigh?
# 126605   How do I get back to my best friend as my lover?
# 6008    As a Navy SEAL do you feel as if people are af...
# 292788                     Why is there only few magnets?
#
#                                                q1_cleaned  \
# 80519          which topic is the most followed in quora?
# 349125  what does it feel like to have sex with a rela...
# 126605                     can i get back my best friend?
# 6008    are there solar systems that act like a double...
# 292788                    why are there only few magnets?
#
#                                                q2_cleaned
# 80519         what topic on quora has the most followers?
# 349125         is it possible to eat more than you weigh?
# 126605   how do i get back to my best friend as my lover?
# 6008    as a navy seal do you feel as if people are af...
# 292788                     why is there only few magnets?

# %% [markdown]
# ## Question Length Analysis

# %%
# find word counts of questions
X_train['q1_len'] = X_train['q1_cleaned'].apply(lambda x: len(str(x).split()))
X_train['q2_len'] = X_train['q2_cleaned'].apply(lambda x: len(str(x).split()))
X_train.head()
# Out:
#             id    qid1    qid2  \
# 80519    51432   91228   91229
# 349125   52249   92541   92542
# 126605  135176  215925  215926
# 6008    184003  281230  281231
# 292788    5971   11714   11715
#
#                                                 question1  \
# 80519          Which topic is the most followed in Quora?
# 349125  What does it feel like to have sex with a rela...
# 126605                     Can I get back my best friend?
# 6008    Are there solar systems that act like a double...
# 292788                    Why are there only few magnets?
#
#                                                 question2  \
# 80519         What topic on Quora has the most followers?
# 349125         Is it possible to eat more than you weigh?
# 126605   How do I get back to my best friend as my lover?
# 6008    As a Navy SEAL do you feel as if people are af...
# 292788                     Why is there only few magnets?
#
#                                                q1_cleaned  \
# 80519          which topic is the most followed in quora?
# 349125  what does it feel like to have sex with a rela...
# 126605                     can i get back my best friend?
# 6008    are there solar systems that act like a double...
# 292788                    why are there only few magnets?
#
#                                                q2_cleaned  q1_len  q2_len
# 80519         what topic on quora has the most followers?       8       8
# 349125         is it possible to eat more than you weigh?      13       9
# 126605   how do i get back to my best friend as my lover?       7      12
# 6008    as a navy seal do you feel as if people are af...      10      20
# 292788                     why is there only few magnets?       6       6

# %%
X_train['q1_len'].describe()
# Out:
# count    327461.000000
# mean         11.155331
# std           5.590374
# min           0.000000
# 25%           8.000000
# 50%          10.000000
# 75%          13.000000
# max         128.000000
# Name: q1_len, dtype: float64

# %%
X_train['q2_len'].describe()
# Out:
# count    327461.000000
# mean         11.401483
# std           6.471944
# min           0.000000
# 25%           7.000000
# 50%          10.000000
# 75%          13.000000
# max         248.000000
# Name: q2_len, dtype: float64

# %%
plt.figure(figsize=(10, 6))
ax = sns.boxplot(data=X_train[['q1_len', 'q2_len']], orient='h')
ax.set_xlim(0, 125)

plt.title('Box Plot of Question Lengths')
plt.xlabel('Length')
plt.ylabel('Question')
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.hist([X_train['q1_len'], X_train['q2_len']], bins=100, label=['Question 1', 'Question 2'], range=(0, 250))
plt.title('Histogram of Question Lengths')
plt.xlabel('Length')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# #### Determining Ideal Sequence Length

# %%
q1_len = X_train['q1_len']
q2_len = X_train['q2_len']

q1_iqr = q1_len.quantile(0.75) - q1_len.quantile(0.25)
q1_outlier = q1_len.quantile(0.75) + 1.5 * q1_iqr

q2_iqr = q2_len.quantile(0.75) - q2_len.quantile(0.25)
q2_outlier = q2_len.quantile(0.75) + 1.5 * q2_iqr
print(f"question 1 length outlier: {q1_outlier}")
print(f"question 2 length outlier: {q2_outlier}")
# Out:
# question 1 length outlier: 20.5
# question 2 length outlier: 22.0

# %% [markdown]
# Both questions lengths are such that the outlier value (according to the $1.5 \cdot IQR$ rule) is 22 words.
#
# We will choose a sequnce length of 30 to be safe.

# %% [markdown]
# ## Tokenization

# %% [markdown]
# #### Bert Tokenizer
#
# Tokenizer used will be changed to see if there is an improvement in performance.

# %%
# tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

# %%
# X_train['q1_tokens'] = X_train['q1_cleaned'].apply(tokenizer.tokenize)
# X_train['q2_tokens'] = X_train['q2_cleaned'].apply(tokenizer.tokenize)

# %% [markdown]
# #### `nltk` Tokenizer
#
# Standard `nltk` tokenizer is used instead of BERT tokenizer. Reason is that BERT tokenizer might be more suited for BERT than for this use case.

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
X_train['q1_tokens'] = X_train['q1_cleaned'].apply(word_tokenize)
X_train['q2_tokens'] = X_train['q2_cleaned'].apply(word_tokenize)
X_train.head()
# Out:
#             id    qid1    qid2  \
# 80519    51432   91228   91229
# 349125   52249   92541   92542
# 126605  135176  215925  215926
# 6008    184003  281230  281231
# 292788    5971   11714   11715
#
#                                                 question1  \
# 80519          Which topic is the most followed in Quora?
# 349125  What does it feel like to have sex with a rela...
# 126605                     Can I get back my best friend?
# 6008    Are there solar systems that act like a double...
# 292788                    Why are there only few magnets?
#
#                                                 question2  \
# 80519         What topic on Quora has the most followers?
# 349125         Is it possible to eat more than you weigh?
# 126605   How do I get back to my best friend as my lover?
# 6008    As a Navy SEAL do you feel as if people are af...
# 292788                     Why is there only few magnets?
#
#                                                q1_cleaned  \
# 80519          which topic is the most followed in quora?
# 349125  what does it feel like to have sex with a rela...
# 126605                     can i get back my best friend?
# 6008    are there solar systems that act like a double...
# 292788                    why are there only few magnets?
#
#                                                q2_cleaned  \
# 80519         what topic on quora has the most followers?
# 349125         is it possible to eat more than you weigh?
# 126605   how do i get back to my best friend as my lover?
# 6008    as a navy seal do you feel as if people are af...
# 292788                     why is there only few magnets?
#
#                                                 q1_tokens  \
# 80519   [which, topic, is, the, most, followed, in, qu...
# 349125  [what, does, it, feel, like, to, have, sex, wi...
# 126605           [can, i, get, back, my, best, friend, ?]
# 6008    [are, there, solar, systems, that, act, like, ...
# 292788           [why, are, there, only, few, magnets, ?]
#
#                                                 q2_tokens
# 80519   [what, topic, on, quora, has, the, most, follo...
# 349125  [is, it, possible, to, eat, more, than, you, w...
# 126605  [how, do, i, get, back, to, my, best, friend, ...
# 6008    [as, a, navy, seal, do, you, feel, as, if, peo...
# 292788            [why, is, there, only, few, magnets, ?]

# %% [markdown]
# ## Word2Vec Model Trained on Questions Dataset

# %%
qqp_w2v = Word2Vec.load('/content/drive/MyDrive/ay2324 sem1/cs3244/project/old models/word2_vec_simple_classifier.model')

# %%
qqp_w2v.wv.similarity('singapore', 'malaysia')
# Out:
# 0.9810013

# %%
qqp_w2v.wv.most_similar('cat')
# Out:
# [('bitsat', 0.982618510723114),
#  ('psat', 0.9801468849182129),
#  ('clat', 0.9732540845870972),
#  ('revise', 0.9686999917030334),
#  ('xat', 0.968235433101654),
#  ('cpt', 0.9669320583343506),
#  ('mock', 0.9658421874046326),
#  ('preparing', 0.9658040404319763),
#  ('sat', 0.9647274017333984),
#  ('ntse', 0.964547872543335)]

# %%
len(qqp_w2v.wv)
# Out:
# 74083

# %% [markdown]
# ## Generate Word Embeddings with Pretrained Word2Vec Model

# %%
w2v_vecs = gensim.downloader.load('word2vec-google-news-300')
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
len(w2v_vecs)
# Out:
# 3000000

# %%
w2v_vecs.most_similar('cat')
# Out:
# [('cats', 0.8099379539489746),
#  ('dog', 0.760945737361908),
#  ('kitten', 0.7464985251426697),
#  ('feline', 0.7326234579086304),
#  ('beagle', 0.7150582671165466),
#  ('puppy', 0.7075453400611877),
#  ('pup', 0.6934291124343872),
#  ('pet', 0.6891531348228455),
#  ('felines', 0.6755931973457336),
#  ('chihuahua', 0.6709762215614319)]

# %%
EMBEDDING_DIM = 300 # word2vec embeddings size
MAX_SEQ_LENGTH = 30

def get_embeddings(tokens, embedding_dim=EMBEDDING_DIM, max_sequence_length=MAX_SEQ_LENGTH):
    embeddings = torch.zeros((max_sequence_length, embedding_dim))

    for i, token in enumerate(tokens):
        if i >= max_sequence_length:
            break

        if token in w2v_vecs:
            embeddings[i] = torch.tensor(w2v_vecs[token])
        else:
            continue # ignore OOV tokens
    return embeddings

# %%
# requires too much RAM, so cannot precompute
# X_train['q1_embeddings'] = X_train['q1_cleaned'].apply(get_embeddings)
# X_train['q2_embeddings'] = X_train['q2_cleaned'].apply(get_embeddings)

# %% [markdown]
# ## Capturing Question Semantics with an LSTM

# %%
class LSTMModel(nn.Module):

    def __init__(self, embedding_dim, hidden_size, num_layers, dropout_rate):
        super(LSTMModel, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers

        self.lstm = nn.LSTM(embedding_dim, hidden_size, num_layers, batch_first=True, dropout=dropout_rate).to(device)

    def forward(self, x):
        # initialize hidden state and context
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)

        out, (hn, cn) = self.lstm(x, (h0, c0))

        # return sum of all the final hidden states across the LSTM layers
        return torch.sum(hn, dim=0)

# %% [markdown]
# ## Siamese Network with Cosine Similarity and Contrastive Loss

# %%
class SiameseNetworkCosineSim(nn.Module):

    def __init__(self, base_model):
        super(SiameseNetworkCosineSim, self).__init__()
        self.base_model = base_model

    def forward(self, q1_embeddings, q2_embeddings):
        embedding1 = self.base_model(q1_embeddings).squeeze(0)
        embedding2 = self.base_model(q2_embeddings).squeeze(0)

        similarity = F.cosine_similarity(embedding1, embedding2, dim=1)
        return similarity  # output is cosine similarity

# %%
class ModifiedContrastiveLoss(nn.Module):

    def __init__(self, similar_margin, dissimilar_margin):
        super(ModifiedContrastiveLoss, self).__init__()
        self.similar_margin = similar_margin
        self.dissimilar_margin = dissimilar_margin

    def forward(self, cossim, label):
        # similar_margin must be high, i.e. if duplicate, cossim must be above similar_margin for the loss to be 0
        duplicate_loss = label * torch.clamp(self.similar_margin - cossim, min=0)

        # dissimilar_margin must be low, i.e. if not duplicate, cossim must be lower than dissimilar_margin for the loss to be 0
        not_duplicate_loss = (1 - label) * torch.clamp(cossim - self.dissimilar_margin, min=0)

        loss = duplicate_loss + not_duplicate_loss
        return loss.mean()

# %% [markdown]
# ## Siamese Network with L1 Distance and Fully Connected Layer

# %%
class L1DistanceLayer(nn.Module):

    def __init__(self):
        super(L1DistanceLayer, self).__init__()

    def forward(self, embedding1, embedding2):
        l1_dist = torch.abs(embedding1 - embedding2)
        return l1_dist

class SiameseNetworkWithL1Distance(nn.Module):

    def __init__(self, base_model, embedding_dim, num_layers, hidden_dim, dropout_rate):
        super(SiameseNetworkWithL1Distance, self).__init__()
        self.base_model = base_model
        self.l1_distance = L1DistanceLayer()

        fc_layers = []
        fc_layers.append(nn.Linear(embedding_dim, hidden_dim))
        fc_layers.append(nn.ReLU())
        fc_layers.append(nn.Dropout(dropout_rate))

        for _ in range(num_layers - 2):
            # out_dim = hidden_dim // 2
            fc_layers.append(nn.Linear(hidden_dim, hidden_dim))
            fc_layers.append(nn.ReLU())
            fc_layers.append(nn.Dropout(dropout_rate))
            # hidden_dim = out_dim

        fc_layers.append(nn.Linear(hidden_dim, 1))
        fc_layers.append(nn.Sigmoid())

        self.fc = nn.Sequential(*fc_layers)

    def forward(self, q1_embeddings, q2_embeddings):
        embedding1 = self.base_model(q1_embeddings).squeeze(0)
        embedding2 = self.base_model(q2_embeddings).squeeze(0)

        l1_dist = self.l1_distance(embedding1, embedding2)

        output = self.fc(l1_dist)
        return output

# %% [markdown]
# ## Integrating Everything

# %% [markdown]
# ### Dataset and Data Loader

# %%
class DuplicateQuestionDataset(Dataset):

    def __init__(self, questions, labels):
        self.questions = questions
        self.labels = labels
        self.embedding_dim = EMBEDDING_DIM

    def __len__(self):
        return len(self.questions)

    def __getitem__(self, idx):
        row = self.questions.iloc[idx]
        q1_tokens, q2_tokens = row[['q1_tokens', 'q2_tokens']]
        ind = row.name

        # bottleneck
        q1_embeddings = get_embeddings(q1_tokens, embedding_dim, max_sequence_length=MAX_SEQ_LENGTH).to(device)
        q2_embeddings = get_embeddings(q2_tokens, embedding_dim, max_sequence_length=MAX_SEQ_LENGTH).to(device)

        label = torch.tensor(self.labels.iloc[idx]).to(device)

        return ind, q1_embeddings, q2_embeddings, label

# %% [markdown]
# ### Preprocess  Validation and Test Datasets

# %%
def preprocess(df):
    df['q1_cleaned'] = df['question1'].apply(clean_text)
    df['q2_cleaned'] = df['question2'].apply(clean_text)

    df['q1_tokens'] = df['q1_cleaned'].apply(word_tokenize)
    df['q2_tokens'] = df['q2_cleaned'].apply(word_tokenize)

    return df

# %%
X_dev = preprocess(X_dev)
X_dev.head()
# Out:
#             id    qid1    qid2  \
# 215130  328831  455423  455424
# 234600   41794   75402   75403
# 118406  184181   56834  281459
# 284746   61939   50127   69389
# 300683  352765  481723   13812
#
#                                                 question1  \
# 215130  Why do some people think that having a baby is...
# 234600  How vulnerable are paratroopers on their desce...
# 118406               Examples of sole proprietorship? The
# 284746  Why don't I get answers for some of my questio...
# 300683               Do Kashmiris wants to join Pakistan?
#
#                                                 question2  \
# 215130                   Why is having a baby a blessing?
# 234600            Are conventional paratroopers obsolete?
# 118406              How are sole proprietorships started?
# 284746  Why do some questions get more answers here in...
# 300683  Do the people of Kashmir want to join Pakistan...
#
#                                                q1_cleaned  \
# 215130  why do some people think that having a baby is...
# 234600  how vulnerable are paratroopers on their desce...
# 118406               examples of sole proprietorship? the
# 284746  why don t i get answers for some of my questio...
# 300683               do kashmiris wants to join pakistan?
#
#                                                q2_cleaned  \
# 215130                   why is having a baby a blessing?
# 234600            are conventional paratroopers obsolete?
# 118406              how are sole proprietorships started?
# 284746  why do some questions get more answers here in...
# 300683  do the people of kashmir want to join pakistan...
#
#                                                 q1_tokens  \
# 215130  [why, do, some, people, think, that, having, a...
# 234600  [how, vulnerable, are, paratroopers, on, their...
# 118406       [examples, of, sole, proprietorship, ?, the]
# 284746  [why, don, t, i, get, answers, for, some, of, ...
# 300683      [do, kashmiris, wants, to, join, pakistan, ?]
#
#                                                 q2_tokens
# 215130         [why, is, having, a, baby, a, blessing, ?]
# 234600     [are, conventional, paratroopers, obsolete, ?]
# 118406      [how, are, sole, proprietorships, started, ?]
# 284746  [why, do, some, questions, get, more, answers,...
# 300683  [do, the, people, of, kashmir, want, to, join,...

# %%
X_test = preprocess(X_test)
X_test.head()
# Out:
#        id    qid1    qid2                                          question1  \
# 0  201359  303345  303346            Why are African-Americans so beautiful?
# 1  263843   69383  380476  I want to pursue PhD in Computer Science about...
# 2  172974  266948  175089      Is there a reason why we should travel alone?
# 3   15329   29298   29299  Why are people so obsessed with having a girlf...
# 4  209794  314169  314170  What are some good baby girl names starting wi...
#
#                                            question2  \
# 0                    Why are hispanics so beautiful?
# 1  I handle social media for a non-profit. Should...
# 2             What are some reasons to travel alone?
# 3                How can a single male have a child?
# 4  What are some good baby girl names starting wi...
#
#                                           q1_cleaned  \
# 0            why are african americans so beautiful?
# 1  i want to pursue phd in computer science about...
# 2      is there a reason why we should travel alone?
# 3  why are people so obsessed with having a girlf...
# 4  what are some good baby girl names starting wi...
#
#                                           q2_cleaned  \
# 0                    why are hispanics so beautiful?
# 1  i handle social media for a non profit  should...
# 2             what are some reasons to travel alone?
# 3                how can a single male have a child?
# 4  what are some good baby girl names starting wi...
#
#                                            q1_tokens  \
# 0   [why, are, african, americans, so, beautiful, ?]
# 1  [i, want, to, pursue, phd, in, computer, scien...
# 2  [is, there, a, reason, why, we, should, travel...
# 3  [why, are, people, so, obsessed, with, having,...
# 4  [what, are, some, good, baby, girl, names, sta...
#
#                                            q2_tokens
# 0            [why, are, hispanics, so, beautiful, ?]
# 1  [i, handle, social, media, for, a, non, profit...
# 2   [what, are, some, reasons, to, travel, alone, ?]
# 3     [how, can, a, single, male, have, a, child, ?]
# 4  [what, are, some, good, baby, girl, names, sta...

# %%
# batch size
batch_size = 128

train_dataset = DuplicateQuestionDataset(X_train, y_train)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

val_dataset = DuplicateQuestionDataset(X_dev, y_dev)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True)

test_dataset = DuplicateQuestionDataset(X_test, y_test)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# ### Hyperparameters

# %%
# LSTM hyperparameters
embedding_dim = 300
lstm_hidden_size = 300
num_lstm_layers = 3
lstm_dropout_rate = 0 # we are only using 1 layer

#FCN Hyperparameters
fcn_hidden_size = 300
num_fcn_layers = 4
fcn_dropout_rate = 0

learning_rate = 0.001

# %%
# for modified contrastive loss
# similar_margin = 0.75
# dissimilar_margin = -0.5

# %% [markdown]
# ### Model Initialisation

# %%
base_model = LSTMModel(embedding_dim, lstm_hidden_size, num_lstm_layers, lstm_dropout_rate).to(device)
siamese_model = SiameseNetworkWithL1Distance(base_model, lstm_hidden_size, num_fcn_layers, fcn_hidden_size, fcn_dropout_rate).to(device)

siamese_model.train()
# Out:
# SiameseNetworkWithL1Distance(
#   (base_model): LSTMModel(
#     (lstm): LSTM(300, 300, num_layers=3, batch_first=True)
#   )
#   (l1_distance): L1DistanceLayer()
#   (fc): Sequential(
#     (0): Linear(in_features=300, out_features=300, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0, inplace=False)
#     (3): Linear(in_features=300, out_features=300, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0, inplace=False)
#     (6): Linear(in_features=300, out_features=300, bias=True)
#     (7): ReLU()
#     (8): Dropout(p=0, inplace=False)
#     (9): Linear(in_features=300, out_features=1, bias=True)
#     (10): Sigmoid()
#   )
# )

# %%
# base_model = LSTMModel(embedding_dim, hidden_size, num_layers).to(device)
# siamese_model = SiameseNetworkCosineSim(base_model).to(device)

# siamese_model.train()

# %% [markdown]
# ### Optimizers & Loss

# %% [markdown]
# The modified contrastive loss did not work as expected. Extremely low accuracy scores were obtained, which was worse than random chance (around 30-40%) which meant that the model might have been optimising for something else.

# %%
# optimizer = torch.optim.Adam(siamese_model.parameters(), lr=learning_rate)
# criterion = ModifiedContrastiveLoss(similar_margin, dissimilar_margin)

# %%
optimizer = torch.optim.Adam(siamese_model.parameters(), lr=learning_rate)
criterion = nn.BCELoss()

# %%
total_params = sum(p.numel() for p in siamese_model.parameters())
total_params
# Out:
# 2438401

# %% [markdown]
# ## Model Training

# %%
num_epochs = 2
lossi = []
threshold = 0.5

base_lstm_path = '/content/drive/MyDrive/ay2324 sem1/cs3244/project/lstm_model.pth'
siamese_model_path = '/content/drive/MyDrive/ay2324 sem1/cs3244/project/siamese_model.pth'

siamese_model.train()

for epoch in range(num_epochs):
    total_loss = 0

    for _, q1_embeddings, q2_embeddings, labels in tqdm(train_loader):
        optimizer.zero_grad()

        output = siamese_model(q1_embeddings, q2_embeddings)
        loss = criterion(output.squeeze(1), labels.float())
        loss.backward()
        optimizer.step()

        lossi.append(loss.item())
        total_loss += loss.item()

    print(f"Epoch {epoch+1}, Loss: {total_loss/len(train_loader):.4f}")

    with torch.no_grad():
        true_labels_val = []
        predicted_scores_val = []
        val_indices = []

        for ind, q1_embeddings, q2_embeddings, labels in tqdm(val_loader):
            outputs = siamese_model(q1_embeddings, q2_embeddings)
            predicted = (outputs > threshold).float().view(-1)

            true_labels_val.extend(labels.cpu().numpy())
            predicted_scores_val.extend(outputs.cpu().numpy())
            val_indices.extend(ind)

    true_labels_val = np.array(true_labels_val)
    predicted_scores_val = np.array(predicted_scores_val)

    accuracy = accuracy_score(true_labels_val, (predicted_scores_val > threshold)) * 100
    print(f"Validation Accuracy: {accuracy:.2f}%")

    # torch.save(base_model.state_dict(), base_lstm_path)
    # torch.save(siamese_model.state_dict(), siamese_model_path)
# Out:
#   0%|          | 0/2559 [00:00<?, ?it/s]
# Epoch 1, Loss: 0.1717
#   0%|          | 0/285 [00:00<?, ?it/s]
# Validation Accuracy: 84.04%
#   0%|          | 0/2559 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-a3fd1dce929e> in <cell line: 10>()
#      19         optimizer.step()
#      20
# ---> 21         lossi.append(loss.item())
#      22         total_loss += loss.item()
#      23
#
# KeyboardInterrupt:

# %% [markdown]
# ### Visualising Loss

# %%
average_lossi = torch.tensor(lossi).view(-1, 853).mean(1)
plt.plot(average_lossi)
plt.title('Training Loss')
# Out:
# Text(0.5, 1.0, 'Training Loss')

# %% [markdown]
# ## Saving Model

# %%
base_lstm_path = '/content/drive/MyDrive/ay2324 sem1/cs3244/project/lstm_model.pth'
siamese_model_path = '/content/drive/MyDrive/ay2324 sem1/cs3244/project/siamese_model.pth'

# %%
torch.save(base_model.state_dict(), base_lstm_path)
torch.save(siamese_model.state_dict(), siamese_model_path)

# %% [markdown]
# ## Loading Model

# %%
base_lstm_path = '/content/drive/MyDrive/ay2324 sem1/cs3244/project/lstm_model.pth'
siamese_model_path = '/content/drive/MyDrive/ay2324 sem1/cs3244/project/siamese_model.pth'

# %%
base_model = LSTMModel(embedding_dim, lstm_hidden_size, num_lstm_layers, lstm_dropout_rate).to(device)
base_model.load_state_dict(torch.load(base_lstm_path))

siamese_model = SiameseNetworkWithL1Distance(base_model, lstm_hidden_size, num_fcn_layers, fcn_hidden_size, fcn_dropout_rate).to(device)
siamese_model.load_state_dict(torch.load(siamese_model_path))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# ### Training Accuracy

# %%
# siamese_model.eval()
threshold = 0.5

with torch.no_grad():
    true_labels_train = []
    predicted_scores_train = []
    train_indices = []

    for ind, q1_embeddings, q2_embeddings, labels in tqdm(train_loader):
        outputs = siamese_model(q1_embeddings, q2_embeddings)
        predicted = (outputs > threshold).float().view(-1)

        true_labels_train.extend(labels.cpu().numpy())
        predicted_scores_train.extend(outputs.cpu().numpy())
        train_indices.extend(ind)

true_labels_train = np.array(true_labels_train)
predicted_scores_train = np.array(predicted_scores_train)

accuracy = accuracy_score(true_labels_train, (predicted_scores_train > threshold)) * 100
print(f"Train Accuracy: {accuracy:.2f}%")
# Out:
#   0%|          | 0/2559 [00:00<?, ?it/s]
# Train Accuracy: 94.02%

# %%
X_train_results = X_train.loc[train_indices, ['question1', 'question2', 'q1_tokens', 'q2_tokens']]
X_train_results['is_duplicate'] = true_labels_train
X_train_results['raw_prediction'] = predicted_scores_train
X_train_results['prediction'] = (predicted_scores_train > threshold).astype(int)
X_train_results.head()
# Out:
#                                                 question1  \
# 79786                 What is Foot & Mouth Disease (FMD)?
# 165576  What are good gifts for a foreign visitor to b...
# 10508                       What is diffusion in biology?
# 284723        How often does the average couple have sex?
# 120264  How we can learn C language easily? Any recomm...
#
#                                                 question2  \
# 79786   Is pathos related to physical description or a...
# 165576  What are good gifts for a foreign visitor to b...
# 10508                 How does diffusion work in biology?
# 284723                     How often do couples have sex?
# 120264                    How can we learn c programming?
#
#                                                 q1_tokens  \
# 79786            [what, is, foot, mouth, disease, fmd, ?]
# 165576  [what, are, good, gifts, for, a, foreign, visi...
# 10508               [what, is, diffusion, in, biology, ?]
# 284723  [how, often, does, the, average, couple, have,...
# 120264  [how, we, can, learn, c, language, easily, ?, ...
#
#                                                 q2_tokens  is_duplicate  \
# 79786   [is, pathos, related, to, physical, descriptio...             0
# 165576  [what, are, good, gifts, for, a, foreign, visi...             0
# 10508        [how, does, diffusion, work, in, biology, ?]             1
# 284723            [how, often, do, couples, have, sex, ?]             1
# 120264           [how, can, we, learn, c, programming, ?]             1
#
#         raw_prediction  prediction
# 79786         0.002705           0
# 165576        0.007943           0
# 10508         0.506529           1
# 284723        0.795284           1
# 120264        0.972447           1

# %%
filepath = '/content/drive/MyDrive/ay2324 sem1/cs3244/project/siamese_lstm_train_results.csv'
X_train_results.to_csv(filepath)

# %% [markdown]
# ### Validation Accuracy

# %%
siamese_model.eval()
threshold = 0.5

with torch.no_grad():
    true_labels_val = []
    predicted_scores_val = []
    val_indices = []

    for ind, q1_embeddings, q2_embeddings, labels in tqdm(val_loader):
        outputs = siamese_model(q1_embeddings, q2_embeddings)
        predicted = (outputs > threshold).float().view(-1)

        true_labels_val.extend(labels.cpu().numpy())
        predicted_scores_val.extend(outputs.cpu().numpy())
        val_indices.extend(ind)

true_labels_val = np.array(true_labels_val)
predicted_scores_val = np.array(predicted_scores_val)

accuracy = accuracy_score(true_labels_val, (predicted_scores_val > threshold)) * 100
print(f"Validation Accuracy: {accuracy:.2f}%")
# Out:
#   0%|          | 0/285 [00:00<?, ?it/s]
# Validation Accuracy: 84.50%

# %%
X_dev_results = X_dev.loc[val_indices, ['question1', 'question2', 'q1_tokens', 'q2_tokens']]
X_dev_results['is_duplicate'] = true_labels_val
X_dev_results['raw_prediction'] = predicted_scores_val
X_dev_results['prediction'] = (predicted_scores_val > threshold).astype(int)
X_dev_results.head()
# Out:
#                                                 question1  \
# 134464  What are the strengths and weaknesses of the i...
# 51513    Why do all my questions need improving on quora?
# 60103   What are the Top mba colleges in india with be...
# 13577                          What your favourite movie?
# 180008  Is getting a Reliance Jio sim a good option fo...
#
#                                                 question2  \
# 134464  Why is the manufacturing sector in India so weak?
# 51513   What is the best way to improve my questions o...
# 60103   Which are the best reputed MBA colleges in India?
# 13577                   Favourite movie of all time? Why?
# 180008  Which SIM card is better Reliance Jio or BSNL ...
#
#                                                 q1_tokens  \
# 134464  [what, are, the, strengths, and, weaknesses, o...
# 51513   [why, do, all, my, questions, need, improving,...
# 60103   [what, are, the, top, mba, colleges, in, india...
# 13577                   [what, your, favourite, movie, ?]
# 180008  [is, getting, a, reliance, jio, sim, a, good, ...
#
#                                                 q2_tokens  is_duplicate  \
# 134464  [why, is, the, manufacturing, sector, in, indi...             0
# 51513   [what, is, the, best, way, to, improve, my, qu...             1
# 60103   [which, are, the, best, reputed, mba, colleges...             1
# 13577        [favourite, movie, of, all, time, ?, why, ?]             1
# 180008  [which, sim, card, is, better, reliance, jio, ...             0
#
#         raw_prediction  prediction
# 134464        0.003966           0
# 51513         0.585000           1
# 60103         0.935044           1
# 13577         0.297989           0
# 180008        0.032293           0

# %%
filepath = '/content/drive/MyDrive/ay2324 sem1/cs3244/project/siamese_lstm_dev_results.csv'
X_dev_results.to_csv(filepath)

# %% [markdown]
# ### Test Accuracy

# %%
siamese_model.eval()
threshold = 0.5

with torch.no_grad():
    true_labels_test = []
    predicted_scores_test = []
    test_indices = []

    for ind, q1_embeddings, q2_embeddings, labels in tqdm(test_loader):
        outputs = siamese_model(q1_embeddings, q2_embeddings)
        predicted = (outputs > threshold).float().view(-1)

        true_labels_test.extend(labels.cpu().numpy())
        predicted_scores_test.extend(outputs.cpu().numpy())
        test_indices.extend(ind)

true_labels_test = np.array(true_labels_test)
predicted_scores_test = np.array(predicted_scores_test)

accuracy = accuracy_score(true_labels_test, (predicted_scores_test > threshold)) * 100
print(f"Test Accuracy: {accuracy:.2f}%")
# Out:
#   0%|          | 0/316 [00:00<?, ?it/s]
# Test Accuracy: 84.09%

# %%
X_test_results = X_test.loc[test_indices, ['question1', 'question2', 'q1_tokens', 'q2_tokens']]
X_test_results['is_duplicate'] = true_labels_test
X_test_results['raw_prediction'] = predicted_scores_test
X_test_results['prediction'] = (predicted_scores_test > threshold).astype(int)
X_test_results.head()
# Out:
#                                                question1  \
# 12530               How do I become a graphics designer?
# 39471  Any Java libraries for debugging and disassemb...
# 33672               Is Quora supporting Hillary Clinton?
# 20444  Do I have to pay VAT if my company is register...
# 37675  Why is Narendra Modi the best Prime Minister f...
#
#                                                question2  \
# 12530  How did you figured out that you want to be a ...
# 39471  Is there any mobile application identified fak...
# 33672  Has Quora turned into a political hack for Cli...
# 20444  Do I have to pay VAT if my company is register...
# 37675  IF not Narendra Modi, who can be the next best...
#
#                                                q1_tokens  \
# 12530     [how, do, i, become, a, graphics, designer, ?]
# 39471  [any, java, libraries, for, debugging, and, di...
# 33672       [is, quora, supporting, hillary, clinton, ?]
# 20444  [do, i, have, to, pay, vat, if, my, company, i...
# 37675  [why, is, narendra, modi, the, best, prime, mi...
#
#                                                q2_tokens  is_duplicate  \
# 12530  [how, did, you, figured, out, that, you, want,...             0
# 39471  [is, there, any, mobile, application, identifi...             0
# 33672  [has, quora, turned, into, a, political, hack,...             1
# 20444  [do, i, have, to, pay, vat, if, my, company, i...             1
# 37675  [if, not, narendra, modi, who, can, be, the, n...             0
#
#        raw_prediction  prediction
# 12530        0.234013           0
# 39471        0.000520           0
# 33672        0.837505           1
# 20444        0.729317           1
# 37675        0.221747           0

# %%
filepath = '/content/drive/MyDrive/ay2324 sem1/cs3244/project/siamese_lstm_test_results.csv'
X_test_results.to_csv(filepath)

# %% [markdown]
# ### Other Classification Metrics

# %%
def print_classification_metrics(dataset='test'):
    labels = {
        'train': (true_labels_train, predicted_scores_train),
        'val': (true_labels_val, predicted_scores_val),
        'test': (true_labels_test, predicted_scores_test)
    }
    true, predicted = labels[dataset]

    print(classification_report(true, (predicted > threshold)))

    fpr, tpr, _ = roc_curve(true, predicted)
    roc_auc = auc(fpr, tpr)

    # Plot the ROC curve
    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUC = {roc_auc:.2f}')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'{dataset.capitalize()} Receiver Operating Characteristic')
    plt.legend(loc='lower right')
    plt.show()

    print(f"AUC-ROC: {roc_auc:.2f}")

# %%
print_classification_metrics(dataset='train')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95    206401
#            1       0.92      0.92      0.92    121060
#
#     accuracy                           0.94    327461
#    macro avg       0.94      0.94      0.94    327461
# weighted avg       0.94      0.94      0.94    327461
# AUC-ROC: 0.98

# %%
print_classification_metrics(dataset='val')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.84      0.87     23067
#            1       0.75      0.84      0.79     13318
#
#     accuracy                           0.84     36385
#    macro avg       0.83      0.84      0.83     36385
# weighted avg       0.85      0.84      0.84     36385
# AUC-ROC: 0.92

# %%
print_classification_metrics(dataset='test')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.87     25545
#            1       0.78      0.79      0.79     14885
#
#     accuracy                           0.84     40430
#    macro avg       0.83      0.83      0.83     40430
# weighted avg       0.84      0.84      0.84     40430
# AUC-ROC: 0.91
